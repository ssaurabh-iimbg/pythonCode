# %% [markdown]
# <a href="https://colab.research.google.com/github/ssaurabh-iimbg/pythonCode/blob/main/classRoutineCopy22May2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

def populate_datetime(date_str):
  """
  Populates a datetime object from a string.

  Args:
    date_str: A string representing the date and time in a valid format.

  Returns:
    A datetime object representing the parsed date and time.
  """

  # Define the format of the date string
  #date_format = "%Y-%m-%d %H:%M:%S"
  date_format = "%d-%m-%Y %H:%M"

  # Parse the date string and create a datetime object
  try:
    date_obj = datetime.strptime(date_str, date_format)
  except ValueError as e:
    raise ValueError("Invalid date string format. Expected format: DD-MM-YYYY HH:MM") from e

  return date_obj

def populate_datetime2(date_str):
  """
  Populates a datetime object from a string.

  Args:
    date_str: A string representing the date and time in a valid format.

  Returns:
    A datetime object representing the parsed date and time.
  """

  # Define the format of the date string
  #date_format = "%Y-%m-%d %H:%M:%S"
  date_format = "%d-%m-%y %H:%M"

  # Parse the date string and create a datetime object
  try:
    date_obj = datetime.strptime(date_str, date_format)
  except ValueError as e:
    raise ValueError("Invalid date string format. Expected format: DD-MM-YYYY HH:MM") from e

  return date_obj

# Example usage
date_str1 = "20-04-2024 10:30"
date_str2 = "10-04-24 10:30"
date_obj1 = populate_datetime(date_str1)
date_obj2 = populate_datetime2(date_str2)
print(date_obj1)
print(date_obj2)
# Out:
# 2024-04-20 10:30:00
# 2024-04-10 10:30:00

# %%
from datetime import datetime
def time_slots_intersect(slot1_start, slot1_end, slot2_start, slot2_end):
  """
  Checks if two time slots intersect with each other.

  Args:
    slot1_start: Start time of the first time slot (datetime object).
    slot1_end: End time of the first time slot (datetime object).
    slot2_start: Start time of the second time slot (datetime object).
    slot2_end: End time of the second time slot (datetime object).

  Returns:
    True if the two time slots intersect, False otherwise.
  """

  # Check if the start of slot2 is between the start and end of slot1
  if slot2_start >= slot1_start and slot2_start < slot1_end:
    return True

  # Check if the end of slot2 is between the start and end of slot1
  if slot2_end > slot1_start and slot2_end <= slot1_end:
    return True

  # Check if slot1 is completely within slot2
  if slot1_start >= slot2_start and slot1_end <= slot2_end:
    return True

  # Otherwise, the time slots do not intersect
  return False

# Example usage
slot1_start = populate_datetime("20-05-2024 15:00")
slot1_end = populate_datetime("20-05-2024 16:30")
slot2_start = populate_datetime("20-05-2024 14:30")
slot2_end = populate_datetime("20-05-2024 15:05")

if time_slots_intersect(slot1_start, slot1_end, slot2_start, slot2_end):
  print("Time slots intersect")
else:
  print("Time slots do not intersect")
# Out:
# Time slots intersect

# %%
import enum

class DayOfWeek(enum.Enum):
    MONDAY = "Monday"
    TUESDAY = "Tuesday"
    WEDNESDAY = "Wednesday"
    THURSDAY = "Thursday"
    FRIDAY = "Friday"
    SATURDAY = "Saturday"
    SUNDAY = "Sunday"

class ProgramName(enum.Enum):
    MBA01SECA = "MBA01SECA"
    MBA01SECB = "MBA01SECB"
    MBA01SECC = "MBA01SECC"
    MBA01SECD = "MBA01SECD"
    DBM01 = "DBM01"
    DBM02 = "DBM02"
    HHM01 = "HHM01"
    HHM02 = "HHM02"
    IPM01SECA = "IPM01SECA"
    IPM01SECB = "IPM01SECB"
    IPM02SECA = "IPM02SECA"
    IPM02SECB = "IPM02SECB"
    IPM03SECA = "IPM03SECA"
    IPM03SECB = "IPM03SECB"

class Year(enum.Enum):
    FIRST = 1
    SECOND = 2
    THIRD = 3

class SectionName(enum.Enum):
    A = "A"
    B = "B"
    C = "C"
    D = "D"

# %%
import datetime
import re

class ClassObj:
    def __init__(self, courseName, facultyName, startTimeStr, endTimeStr, programName):
        # Parse the start and end times into datetime objects
        self.timeSlot = (
            datetime.datetime.strptime(startTimeStr, "%d-%m-%Y %H:%M"),
            datetime.datetime.strptime(endTimeStr, "%d-%m-%Y %H:%M")
        )
        self.startTime = datetime.datetime.strptime(startTimeStr, "%d-%m-%Y %H:%M")
        self.endTime = datetime.datetime.strptime(endTimeStr, "%d-%m-%Y %H:%M")

        self.courseName = courseName
        self.facultyName = facultyName
        self.programName = programName
        self.program, self.year, self.section = self.parse_program_name_demlim_(programName)

    def parse_program_name_demlim_(self, programName):
        # Split the program name by "_"
        parts = programName.split("_")

        # Extract program, year, and section
        if len(parts) == 3:
            program = parts[0]
            year = parts[1]
            section = parts[2]
        elif len(parts) == 2:
            program = parts[0]
            year = parts[1]
            section = None
        else:
            raise ValueError("Invalid program name format")

        return program, year, section

    def parse_program_name(self, programName):
        # Use a regular expression to extract program, year, and section
        match = re.match(r"^([A-Z]{3})(\d{2})(.*)$", programName)

        if match:
            program = match.group(1)
            year = match.group(2)
            section = match.group(3)

            # If section is empty, set it to "Node"
            if not section:
                section = None

            return program, year, section
        else:
            raise ValueError("Invalid program name format")


    def display(self):
        print("Course Name:", self.courseName)
        print("Faculty Name:", self.facultyName)
        print("Time Slot:", self.timeSlot[0].strftime("%d-%m-%Y %H:%M") + " - " + self.timeSlot[1].strftime("%d-%m-%Y %H:%M"))
        print("Program Name:", self.programName)
        print("Program:", self.program)
        print("Year:", self.year)
        print("Section:", self.section)

# Example usage
courseObj = ClassObj(courseName= "Introduction to Python", facultyName="John Doe", startTimeStr= "10-04-2023 10:30", endTimeStr="10-04-2023 11:30", programName="MBADBM_01_SECA")
courseObj.display()
# Out:
# Course Name: Introduction to Python
# Faculty Name: John Doe
# Time Slot: 10-04-2023 10:30 - 10-04-2023 11:30
# Program Name: MBADBM_01_SECA
# Program: MBADBM
# Year: 01
# Section: SECA

# %%
class Faculty:
    def __init__(self, facultyName, facultyEmail=None):
        self.facultyName = facultyName
        self.facultyEmail = facultyEmail
        self.courseList = []

    def insert_course(self, courseObj):
        self.courseList.append(courseObj)


    def display_courses(self):
        print("Courses for", self.facultyName)
        for course in self.courseList:
            print("- Course Name:", course.courseName)
            print("  Time Slot:", course.timeSlot[0].strftime("%d-%m-%Y %H:%M") + " - " + course.timeSlot[1].strftime("%d-%m-%Y %H:%M"))
            print("  Program:", course.program)
            print("  Year:", course.year)
            print("  Section:", course.section)

    def are_classes_non_intersecting(self):
        # Sort the courses by start time
        self.courseList.sort(key=lambda course: course.timeSlot[0])

        # Check for intersections
        for i in range(1, len(self.courseList)):
            prev_course = self.courseList[i-1]
            curr_course = self.courseList[i]

            if curr_course.timeSlot[0] < prev_course.timeSlot[1]:
                return False

        return True

# Example usage
faculty = Faculty("John Doe", "john.doe@example.com")
faculty = Faculty("John Porter")

# Create a course object
courseObj1 = ClassObj("Introduction to Python", "John Doe", "20-05-2024 10:30",  "20-05-2024 11:30", "CSC_23_SECA")
# Create a course object
courseObj2 = ClassObj("Introduction to Data Science", "John Doe", "20-05-2024 13:30",  "20-05-2024 14:30", "CSC_23_SECB")
courseObj3 = ClassObj("Introduction to Data Analytics", "John Doe", "20-05-2024 14:45",  "20-05-2024 15:30", "CSC_23_SECA")
courseObj4 = ClassObj("Introduction to Story Telling with Data", "John Doe", "21-05-2024 10:30",  "21-05-2024 11:30", "CSC_23_SECA")
courseObj5 = ClassObj("Introduction to Artificial Intelligence", "John Doe", "22-05-2024 10:30",  "22-05-2024 11:30", "CSC_23_SECA")

# Insert the course object into the faculty's list of courses
faculty.insert_course(courseObj1)
faculty.insert_course(courseObj2)
faculty.insert_course(courseObj3)
faculty.insert_course(courseObj4)
faculty.insert_course(courseObj5)

# Print the faculty's information
print("Faculty Name:", faculty.facultyName)
print("Faculty Email:", faculty.facultyEmail)
print("Number of Courses:", len(faculty.courseList))
print(faculty.display_courses())
faculty.are_classes_non_intersecting()
# Out:
# Faculty Name: John Porter
# Faculty Email: None
# Number of Courses: 5
# Courses for John Porter
# - Course Name: Introduction to Python
#   Time Slot: 20-05-2024 10:30 - 20-05-2024 11:30
#   Program: CSC
#   Year: 23
#   Section: SECA
# - Course Name: Introduction to Data Science
#   Time Slot: 20-05-2024 13:30 - 20-05-2024 14:30
#   Program: CSC
#   Year: 23
#   Section: SECB
# - Course Name: Introduction to Data Analytics
#   Time Slot: 20-05-2024 14:45 - 20-05-2024 15:30
#   Program: CSC
#   Year: 23
#   Section: SECA
# - Course Name: Introduction to Story Telling with Data
#   Time Slot: 21-05-2024 10:30 - 21-05-2024 11:30
#   Program: CSC
#   Year: 23
#   Section: SECA
# - Course Name: Introduction to Artificial Intelligence
#   Time Slot: 22-05-2024 10:30 - 22-05-2024 11:30
#   Program: CSC
#   Year: 23
#   Section: SECA
# None
# True

# %%
class FacultyGroup:
    def __init__(self):
        self.faculty_list = []

    def add_faculty(self, faculty):
        self.faculty_list.append(faculty)

# %%
class TimeSlot:
    def __init__(self, start_time, finish_time):
        self.start_time = start_time
        self.finish_time = finish_time

# ClassObj: courseName, facultyName, startTimeStr, endTimeStr, programName:
'''
class Program:
    def __init__(self, program_name):
        self.program_name = program_name
        self.schedule = {}

    def add_item(self, date, time_slot, class_objs):
        if date not in self.schedule:
            self.schedule[date] = []
        self.schedule[date].append({
            'time_slot': time_slot,
            'class_objs': class_objs
        })

    def display_schedule(self):
        print(f"Program: {self.program_name}")
        for date, items in self.schedule.items():
            print(f"\nDate: {date}")
            for item in items:
                time_slot = item['time_slot']
                class_objs = item['class_objs']
                class_names = [obj.class_name for obj in class_objs]
                print(f"- Time: {time_slot.start_time}-{time_slot.finish_time}")
                print(f"  Classes: {', '.join(class_names)}")


# Usage example:
program = Program("Bachelor of Science in Computer Science")

time_slot_1 = TimeSlot("08:00", "09:30")
time_slot_2 = TimeSlot("09:45", "11:15")

# Create a course object
courseObj1 = ClassObj("Introduction to Python", "John Doe", "20-05-2024 10:30",  "20-05-2024 11:30", "CSC_23_SECA")
# Create a course object
courseObj2 = ClassObj("Introduction to Data Science", "John Doe", "20-05-2024 13:30",  "20-05-2024 14:30", "CSC_23_SECB")
courseObj3 = ClassObj("Introduction to Data Analytics", "John Doe", "20-05-2024 14:45",  "20-05-2024 15:30", "CSC_23_SECA")
courseObj4 = ClassObj("Introduction to Story Telling with Data", "John Doe", "21-05-2024 10:30",  "21-05-2024 11:30", "CSC_23_SECA")
courseObj5 = ClassObj("Introduction to Artificial Intelligence", "John Doe", "22-05-2024 10:30",  "22-05-2024 11:30", "CSC_23_SECA")


program.add_item("01-01-2023", time_slot_1, [class_obj_1])
program.add_item("01-01-2023", time_slot_2, [class_obj_2])

program.add_item("02-01-2023", time_slot_1, [class_obj_1])
program.add_item("02-01-2023", time_slot_2, [class_obj_2])


# Print the program's schedule
program.display_schedule()
'''
# Out:
# '\nclass Program:\n    def __init__(self, program_name):\n        self.program_name = program_name\n        self.schedule = {}\n\n    def add_item(self, date, time_slot, class_objs):\n        if date not in self.schedule:\n            self.schedule[date] = []\n        self.schedule[date].append({\n            \'time_slot\': time_slot,\n            \'class_objs\': class_objs\n        })\n\n    def display_schedule(self):\n        print(f"Program: {self.program_name}")\n        for date, items in self.schedule.items():\n            print(f"\nDate: {date}")\n            for item in items:\n                time_slot = item[\'time_slot\']\n                class_objs = item[\'class_objs\']\n                class_names = [obj.class_name for obj in class_objs]\n                print(f"- Time: {time_slot.start_time}-{time_slot.finish_time}")\n                print(f"  Classes: {\', \'.join(class_names)}")\n\n\n# Usage example:\nprogram = Program("Bachelor of Science in Computer Science")\n\ntime_slot_1 = TimeSlot("08:00", "09:30")\ntime_slot_2 = TimeSlot("09:45", "11:15")\n\n# Create a course object\ncourseObj1 = ClassObj("Introduction to Python", "John Doe", "20-05-2024 10:30",  "20-05-2024 11:30", "CSC_23_SECA")\n# Create a course object\ncourseObj2 = ClassObj("Introduction to Data Science", "John Doe", "20-05-2024 13:30",  "20-05-2024 14:30", "CSC_23_SECB")\ncourseObj3 = ClassObj("Introduction to Data Analytics", "John Doe", "20-05-2024 14:45",  "20-05-2024 15:30", "CSC_23_SECA")\ncourseObj4 = ClassObj("Introduction to Story Telling with Data", "John Doe", "21-05-2024 10:30",  "21-05-2024 11:30", "CSC_23_SECA")\ncourseObj5 = ClassObj("Introduction to Artificial Intelligence", "John Doe", "22-05-2024 10:30",  "22-05-2024 11:30", "CSC_23_SECA")\n\n\nprogram.add_item("01-01-2023", time_slot_1, [class_obj_1])\nprogram.add_item("01-01-2023", time_slot_2, [class_obj_2])\n\nprogram.add_item("02-01-2023", time_slot_1, [class_obj_1])\nprogram.add_item("02-01-2023", time_slot_2, [class_obj_2])\n\n\n# Print the program\'s schedule\nprogram.display_schedule()\n'

# %%
class Program:
    def __init__(self, program_name):
        self.program_name = program_name
        self.schedule = {}

    def add_item(self, date, time_slot, class_obj):
        if date not in self.schedule:
            self.schedule[date] = []
        found = False
        for item in self.schedule[date]:
            if item['time_slot'] == time_slot:
                item['class_objs'].append(class_obj)
                found = True
                break
        if not found:
            self.schedule[date].append({
                'time_slot': time_slot,
                'class_objs': [class_obj]
            })

    def display_schedule(self):
        print(f"Program: {self.program_name}")
        for date, items in self.schedule.items():
            print(f"\nDate: {date}")
            for item in items:
                time_slot = item['time_slot']
                class_objs = item['class_objs']
                class_names = [obj.courseName for obj in class_objs]
                print(f"- Time: {time_slot.start_time}-{time_slot.finish_time}")
                print(f"  Classes: {', '.join(class_names)}")


# Usage example:
program = Program("Bachelor of Science in Computer Science")

time_slot_1 = TimeSlot("08:00", "09:30")
time_slot_2 = TimeSlot("09:45", "11:15")

#Our class objects
courseObj1 = ClassObj("Introduction to Python", "John Doe", "20-05-2024 10:30",  "20-05-2024 11:30", "CSC_23_SECA")
courseObj2 = ClassObj("Introduction to Data Science", "John Doe", "20-05-2024 13:30",  "20-05-2024 14:30", "CSC_23_SECB")
courseObj3 = ClassObj("Introduction to Data Analytics", "John Doe", "20-05-2024 14:45",  "20-05-2024 15:30", "CSC_23_SECA")
courseObj4 = ClassObj("Introduction to Story Telling with Data", "John Doe", "21-05-2024 10:30",  "21-05-2024 11:30", "CSC_23_SECA")
courseObj5 = ClassObj("Introduction to Artificial Intelligence", "John Doe", "22-05-2024 10:30",  "22-05-2024 11:30", "CSC_23_SECA")


program.add_item("20-05-2024", time_slot_1, courseObj1)
program.add_item("21-05-2024", time_slot_1, courseObj2)
program.add_item("20-05-2024", time_slot_1, courseObj3)
program.add_item("21-05-2024", time_slot_2, courseObj4)


# Display the program's schedule
program.display_schedule()
# Out:
# Program: Bachelor of Science in Computer Science
#
# Date: 20-05-2024
# - Time: 08:00-09:30
#   Classes: Introduction to Python, Introduction to Data Analytics
#
# Date: 21-05-2024
# - Time: 08:00-09:30
#   Classes: Introduction to Data Science
# - Time: 09:45-11:15
#   Classes: Introduction to Story Telling with Data

# %%
from openpyxl import load_workbook
import datetime

class ExcelReader:
    def __init__(self, file_path):
        self.file_path = file_path

    def convert_datetime_format(self,datetime_string):
         datetime_object = datetime.datetime.strptime(datetime_string, "%Y-%m-%d %H:%M")
         new_datetime_string = datetime_object.strftime("%d-%m-%Y %H:%M")

         return new_datetime_string

    def split_time_slot(self,time_slot):
        parts = time_slot.split(" ")
        dateStr = parts[0].strip()
        startEnd = parts[1].split('-')
        start = startEnd[0]
        end  = startEnd[1]
        startTimeStr = dateStr+ " " + start
        endTimeStr = dateStr + " " + end

        return startTimeStr, endTimeStr



    def read_excel(self):
        """
        Reads an Excel file using openpyxl and prints the data in each sheet.
        """

        # Open the Excel file
        workbook = load_workbook(filename=self.file_path)

        # Iterate through the sheets in the workbook
        for sheet in workbook.worksheets:
            # Print the sheet name
            print(f"Sheet: {sheet.title}")

            # Iterate through the rows in the sheet
            for row_idx,row in enumerate(sheet.rows):
                for col_idx, cell in enumerate(row):
                    #print(row_idx,col_idx)

                    if(row_idx !=0 and col_idx not in [0,1]):
                        if(row_idx % 2 != 0):
                            #print(row_idx,col_idx)
                            courseName=str(cell.value)
                            if (cell.value is None):
                                continue
                            else:
                                timeSlot = str(sheet.cell(row=1, column=(col_idx+1)).value)
                                dateStr = str(sheet.cell(row=(row_idx+1), column=1).value)
                                dateStrS = dateStr[:-9]
                                timeSlotStr =  dateStrS + " " + timeSlot
                                startTimeStr, finishTimeStr = self.split_time_slot(timeSlotStr)
                                startTimeStrC = self.convert_datetime_format(startTimeStr)
                                finishTimeStrC = self.convert_datetime_format(finishTimeStr)
                                print(timeSlotStr)
                                facultyName = str(sheet.cell(row=row_idx+2,column=col_idx+1).value)
                                courseObjRead = ClassObj(courseName,facultyName,startTimeStrC, finishTimeStrC,str(sheet.title))
                                print(courseName,facultyName,startTimeStr, finishTimeStr)
                                courseObjRead.display()


                print()

# Usage example:
reader = ExcelReader("/content/sample_data/classScheduleOne.xlsx")
reader.read_excel()
# Out:
# Sheet: MBA_02
#
# 2024-01-29 10:30-12:00
# Management Lesson from Geeta Prof. Vittal Rangan 2024-01-29 10:30 2024-01-29 12:00
# Course Name: Management Lesson from Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 29-01-2024 10:30 - 29-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 12:15-13:45
# Retail Marketing Prof. Nanda Choudhary 2024-01-29 12:15 2024-01-29 13:45
# Course Name: Retail Marketing
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 29-01-2024 12:15 - 29-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 14:45-16:15
# Luxury & Fashion Management Prof. Ramesh Roshan Das Guru 2024-01-29 14:45 2024-01-29 16:15
# Course Name: Luxury & Fashion Management
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 29-01-2024 14:45 - 29-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 16:30-18:00
# Cloud Computing Prof. Gaurav Abhishek Tigga 2024-01-29 16:30 2024-01-29 18:00
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 29-01-2024 16:30 - 29-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 18:15-19:45
# Marketing Strategy (Sec A) Prof. Satish C Ojha 2024-01-29 18:15 2024-01-29 19:45
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 29-01-2024 18:15 - 29-01-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-01-30 10:30-12:00
# Operations Strategy Prof. Ajith Tom James 2024-01-30 10:30 2024-01-30 12:00
# Course Name: Operations Strategy
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 30-01-2024 10:30 - 30-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 12:15-13:45
# Marketing Strategy Prof. Nanda Choudhary 2024-01-30 12:15 2024-01-30 13:45
# Course Name: Marketing Strategy
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 30-01-2024 12:15 - 30-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 14:45-16:15
# Strategic HRM Prof. Remya Latabhavan 2024-01-30 14:45 2024-01-30 16:15
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 30-01-2024 14:45 - 30-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 16:30-18:00
# Strategy & Organizational Leadership Prof. Srividya Raghavan 2024-01-30 16:30 2024-01-30 18:00
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 30-01-2024 16:30 - 30-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 18:15-19:45
# International Finance Prof. Molla Ramizur Rahman 2024-01-30 18:15 2024-01-30 19:45
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 30-01-2024 18:15 - 30-01-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-01-31 08:45-10:15
# Cloud Computing Prof. Gaurav Abhishek Tigga 2024-01-31 08:45 2024-01-31 10:15
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 31-01-2024 08:45 - 31-01-2024 10:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 10:30-12:00
# International Finance, Retail Marketing Prof. Molla Ramizur Rahman, Prof. Nanda Choudhary 2024-01-31 10:30 2024-01-31 12:00
# Course Name: International Finance, Retail Marketing
# Faculty Name: Prof. Molla Ramizur Rahman, Prof. Nanda Choudhary
# Time Slot: 31-01-2024 10:30 - 31-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 12:15-13:45
# International Business Prof. Suresh K G 2024-01-31 12:15 2024-01-31 13:45
# Course Name: International Business
# Faculty Name: Prof. Suresh K G
# Time Slot: 31-01-2024 12:15 - 31-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 14:45-16:15
# Luxury & Fashion Management Prof. Ramesh Roshan Das Guru 2024-01-31 14:45 2024-01-31 16:15
# Course Name: Luxury & Fashion Management
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 31-01-2024 14:45 - 31-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 16:30-18:00
# Management Lesson from Geeta Prof. Vittal Rangan 2024-01-31 16:30 2024-01-31 18:00
# Course Name: Management Lesson from Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 31-01-2024 16:30 - 31-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-02-01 08:45-10:15
# Strategy & Organizational Leadership Prof. Srividya Raghavan 2024-02-01 08:45 2024-02-01 10:15
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 01-02-2024 08:45 - 01-02-2024 10:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-01 14:45-16:15
# Cloud Computing Prof. Gaurav Abhishek Tigga 2024-02-01 14:45 2024-02-01 16:15
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 01-02-2024 14:45 - 01-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-01 16:30-18:00
# Strategy & Organizational Leadership Prof. Srividya Raghavan 2024-02-01 16:30 2024-02-01 18:00
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 01-02-2024 16:30 - 01-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-01 18:15-19:45
# Operations Strategy Prof. Ajith Tom James 2024-02-01 18:15 2024-02-01 19:45
# Course Name: Operations Strategy
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 01-02-2024 18:15 - 01-02-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-02-02 10:30-12:00
# Marketing Strategy Prof. Nanda Choudhary 2024-02-02 10:30 2024-02-02 12:00
# Course Name: Marketing Strategy
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 02-02-2024 10:30 - 02-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-02 12:15-13:45
# International Business Prof. Suresh K G 2024-02-02 12:15 2024-02-02 13:45
# Course Name: International Business
# Faculty Name: Prof. Suresh K G
# Time Slot: 02-02-2024 12:15 - 02-02-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-02 14:45-16:15
# Strategic HRM Prof. Remya Latabhavan 2024-02-02 14:45 2024-02-02 16:15
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 02-02-2024 14:45 - 02-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-02 16:30-18:00
# Investment Banking Prof. Archana Patro 2024-02-02 16:30 2024-02-02 18:00
# Course Name: Investment Banking
# Faculty Name: Prof. Archana Patro
# Time Slot: 02-02-2024 16:30 - 02-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-02-03 10:30-12:00
# Marketing Strategy Prof. Nanda Choudhary 2024-02-03 10:30 2024-02-03 12:00
# Course Name: Marketing Strategy
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 03-02-2024 10:30 - 03-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-03 12:15-13:45
# Investment Banking Guest Session 2024-02-03 12:15 2024-02-03 13:45
# Course Name: Investment Banking
# Faculty Name: Guest Session
# Time Slot: 03-02-2024 12:15 - 03-02-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-03 14:45-16:15
# International Finance Prof. Molla Ramizur Rahman 2024-02-03 14:45 2024-02-03 16:15
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 03-02-2024 14:45 - 03-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-03 16:30-18:00
# Strategic HRM Prof. Remya Latabhavan 2024-02-03 16:30 2024-02-03 18:00
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 03-02-2024 16:30 - 03-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None

# %%
from openpyxl import load_workbook
import datetime

class ExcelReader:
    def __init__(self, file_path):
        self.file_path = file_path

    def convert_datetime_format(self,datetime_string):
         datetime_object = datetime.datetime.strptime(datetime_string, "%Y-%m-%d %H:%M")
         new_datetime_string = datetime_object.strftime("%d-%m-%Y %H:%M")

         return new_datetime_string

    def split_time_slot(self,time_slot):
        parts = time_slot.split(" ")
        dateStr = parts[0].strip()
        startEnd = parts[1].split('-')
        start = startEnd[0]
        end  = startEnd[1]
        startTimeStr = dateStr+ " " + start
        endTimeStr = dateStr + " " + end

        return startTimeStr, endTimeStr



    def read_excel(self):
        """
        Reads an Excel file using openpyxl and prints the data in each sheet.
        """

        # Open the Excel file
        workbook = load_workbook(filename=self.file_path)

        # Iterate through the sheets in the workbook
        for sheet in workbook.worksheets:
            # Print the sheet name
            print(f"Sheet: {sheet.title}")

            # Iterate through the rows in the sheet
            for row_idx,row in enumerate(sheet.rows):
                for col_idx, cell in enumerate(row):
                    #print(row_idx,col_idx)

                    if(row_idx !=0 and col_idx not in [0,1]):
                        if(row_idx % 2 != 0):
                            #print(row_idx,col_idx)
                            courseName=str(cell.value)
                            if (cell.value is None):
                                continue
                            else:
                                timeSlot = str(sheet.cell(row=1, column=(col_idx+1)).value)
                                dateStr = str(sheet.cell(row=(row_idx+1), column=1).value)
                                dateStrS = dateStr[:-9]
                                timeSlotStr =  dateStrS + " " + timeSlot
                                startTimeStr, finishTimeStr = self.split_time_slot(timeSlotStr)
                                startTimeStrC = self.convert_datetime_format(startTimeStr)
                                finishTimeStrC = self.convert_datetime_format(finishTimeStr)
                                #print(timeSlotStr)


                                facultyName = str(sheet.cell(row=row_idx+2,column=col_idx+1).value)
                                ''' Course and Faculty Name can be a list, so need to make a
                                    list of ClassObj
                                '''
                                courseNameL = courseName.split(',')
                                facultyNameL = facultyName.split(',')

                                courseFacultyList = list(zip(courseNameL, facultyNameL))

                                for c,f in courseFacultyList:

                                    courseObjRead = ClassObj(c,f,startTimeStrC, finishTimeStrC,str(sheet.title))
                                    #print(courseName,facultyName,startTimeStr, finishTimeStr)
                                    courseObjRead.display()


                print()

# Usage example:
reader = ExcelReader("/content/sample_data/classScheduleAllT.xlsx")
reader.read_excel()
# Out:
# Sheet: MBA_02
#
# Course Name: Management Lesson from Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 29-01-2024 10:30 - 29-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Retail Marketing
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 29-01-2024 12:15 - 29-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Luxury & Fashion Management
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 29-01-2024 14:45 - 29-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 29-01-2024 16:30 - 29-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 29-01-2024 18:15 - 29-01-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Course Name: Operations Strategy
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 30-01-2024 10:30 - 30-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 30-01-2024 12:15 - 30-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name:  Marketing Strategy (Sec B)
# Faculty Name:  Prof. Nanda Choudhary
# Time Slot: 30-01-2024 12:15 - 30-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 30-01-2024 14:45 - 30-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 30-01-2024 16:30 - 30-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 30-01-2024 18:15 - 30-01-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 31-01-2024 08:45 - 31-01-2024 10:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 31-01-2024 10:30 - 31-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name:  Retail Marketing
# Faculty Name:  Prof. Nanda Choudhary
# Time Slot: 31-01-2024 10:30 - 31-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: International Business
# Faculty Name: Prof. Suresh K G
# Time Slot: 31-01-2024 12:15 - 31-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Luxury & Fashion Management
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 31-01-2024 14:45 - 31-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Management Lesson from Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 31-01-2024 16:30 - 31-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 01-02-2024 08:45 - 01-02-2024 10:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 01-02-2024 14:45 - 01-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 01-02-2024 16:30 - 01-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Operations Strategy
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 01-02-2024 18:15 - 01-02-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Course Name: Marketing Strategy (Sec B)
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 02-02-2024 10:30 - 02-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: International Business
# Faculty Name: Prof. Suresh K G
# Time Slot: 02-02-2024 12:15 - 02-02-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 02-02-2024 14:45 - 02-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Investment Banking
# Faculty Name: Prof. Archana Patro
# Time Slot: 02-02-2024 16:30 - 02-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 03-02-2024 10:30 - 03-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name:  Marketing Strategy (Sec B)
# Faculty Name:  Prof. Nanda Choudhary
# Time Slot: 03-02-2024 10:30 - 03-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Investment Banking
# Faculty Name: Guest Session
# Time Slot: 03-02-2024 12:15 - 03-02-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 03-02-2024 14:45 - 03-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 03-02-2024 16:30 - 03-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Sheet: MBA_01_SECA
#
# Course Name: 6:Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 29-01-2024 11:15 - 29-01-2024 12:45
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Thasni T
# Time Slot: 29-01-2024 15:30 - 29-01-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Business Data Analytics
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 29-01-2024 17:00 - 29-01-2024 18:30
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# Course Name: Business Research Methodology
# Faculty Name: Prof. Sk Abu Khalek
# Time Slot: 30-01-2024 09:30 - 30-01-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Strategic Management
# Faculty Name: Prof. Amit Srivastava
# Time Slot: 30-01-2024 11:15 - 30-01-2024 12:45
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 30-01-2024 15:30 - 30-01-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# Course Name: Business Data Analytics
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 31-01-2024 09:30 - 31-01-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Thasni T
# Time Slot: 31-01-2024 11:15 - 31-01-2024 12:45
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# Course Name: Business Research Methodology
# Faculty Name: Prof. Sk Abu Khalek
# Time Slot: 01-02-2024 09:30 - 01-02-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Strategic Management
# Faculty Name: Prof. Amit Srivastava
# Time Slot: 01-02-2024 15:30 - 01-02-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# Course Name: Operation Management
# Faculty Name: Prof. Chiranjit Das
# Time Slot: 02-02-2024 09:30 - 02-02-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# Course Name: Marketing Management III
# Faculty Name: Prof. Satish C. Ojha
# Time Slot: 02-02-2024 15:30 - 02-02-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
#
#
#
# Sheet: MBA_01_SECB
#
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Suresh KG
# Time Slot: 29-01-2024 11:15 - 29-01-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Business Data Analytics
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 29-01-2024 15:30 - 29-01-2024 17:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 29-01-2024 17:00 - 29-01-2024 18:30
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 30-01-2024 09:30 - 30-01-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Business Research Methodology
# Faculty Name: Prof. Amresh Kumar
# Time Slot: 30-01-2024 11:15 - 30-01-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Operation Management
# Faculty Name: Prof. Rohit Agarwal
# Time Slot: 30-01-2024 15:30 - 30-01-2024 17:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# Course Name: Marketing Management III
# Faculty Name: Prof. Aditi Sharma
# Time Slot: 31-01-2024 09:30 - 31-01-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Business Data Analytics
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 31-01-2024 11:15 - 31-01-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 01-02-2024 09:30 - 01-02-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Business Research Methodology
# Faculty Name: Prof. Amresh Kumar
# Time Slot: 01-02-2024 15:30 - 01-02-2024 17:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 02-02-2024 09:30 - 02-02-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# Course Name: Operation Management
# Faculty Name: Prof. Rohit Agarwal
# Time Slot: 02-02-2024 11:15 - 02-02-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
#
#
# Sheet: MBA_01_SECC
#
# Course Name: Business Data Analytics
# Faculty Name: Prof. Gaurav Tigga
# Time Slot: 29-01-2024 11:15 - 29-01-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 29-01-2024 15:30 - 29-01-2024 17:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Aviral K Tiwary
# Time Slot: 29-01-2024 17:00 - 29-01-2024 18:30
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 30-01-2024 09:30 - 30-01-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Operation Management
# Faculty Name: Prof. Shashank Kumar
# Time Slot: 30-01-2024 11:15 - 30-01-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Business Research Methodology
# Faculty Name: Prof. Chandan Parsad
# Time Slot: 30-01-2024 15:30 - 30-01-2024 17:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Aviral K Tiwary
# Time Slot: 31-01-2024 09:30 - 31-01-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Marketing Management III
# Faculty Name: Prof. Satish C. Ojha
# Time Slot: 31-01-2024 11:15 - 31-01-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 01-02-2024 09:30 - 01-02-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 01-02-2024 15:30 - 01-02-2024 17:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# Course Name: Operation Management
# Faculty Name: Prof. Shashank Kumar
# Time Slot: 02-02-2024 09:30 - 02-02-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 02-02-2024 11:15 - 02-02-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
#
#
# Sheet: MBADBM_02
# Sheet: MBAHHM_01
#
# Course Name: Research Methodology for Healthcare
# Faculty Name: Prof. Raghunathan Krishnakumar
# Time Slot: 29-01-2024 10:45 - 29-01-2024 12:15
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# Course Name: Service Leadership in Healthcare
# Faculty Name: Prof. Teena Bharti
# Time Slot: 29-01-2024 13:15 - 29-01-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 29-01-2024 15:00 - 29-01-2024 16:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# Course Name: Digital Transformation for Healthcare
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 30-01-2024 09:00 - 30-01-2024 10:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# Course Name: Entrepreneurship & New Venture Planning for Healthcare
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 30-01-2024 13:15 - 30-01-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# Course Name: Research Methodology for Healthcare
# Faculty Name: Prof. Raghunathan Krishnakumar
# Time Slot: 31-01-2024 10:45 - 31-01-2024 12:15
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 31-01-2024 13:15 - 31-01-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# Course Name: Service Leadership in Healthcare
# Faculty Name: Prof. Teena Bharti
# Time Slot: 31-01-2024 15:00 - 31-01-2024 16:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# Course Name: Digital Transformation for Healthcare
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 01-02-2024 09:00 - 01-02-2024 10:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# Course Name: Entrepreneurship & New Venture Planning for Healthcare
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 02-02-2024 13:15 - 02-02-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# Course Name: Service Leadership in Healthcare
# Faculty Name: Prof. Teena Bharti
# Time Slot: 02-02-2024 15:00 - 02-02-2024 16:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
#
# Sheet: MBAHHM_02
# Sheet: IPM_01_SECA
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b2cedb6b061c> in <cell line: 82>()
#      80 # Usage example:
#      81 reader = ExcelReader("/content/sample_data/classScheduleAllT.xlsx")
# ---> 82 reader.read_excel()
#
# <ipython-input-16-b2cedb6b061c> in read_excel(self)
#      56                                 startTimeStr, finishTimeStr = self.split_time_slot(timeSlotStr)
#      57                                 startTimeStrC = self.convert_datetime_format(startTimeStr)
# ---> 58                                 finishTimeStrC = self.convert_datetime_format(finishTimeStr)
#      59                                 #print(timeSlotStr)
#      60
#
# <ipython-input-16-b2cedb6b061c> in convert_datetime_format(self, datetime_string)
#       7
#       8     def convert_datetime_format(self,datetime_string):
# ----> 9          datetime_object = datetime.datetime.strptime(datetime_string, "%Y-%m-%d %H:%M")
#      10          new_datetime_string = datetime_object.strftime("%d-%m-%Y %H:%M")
#      11
#
# /usr/lib/python3.10/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# /usr/lib/python3.10/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
#     350                          (data_string, format))
#     351     if len(data_string) != found.end():
#
# ValueError: time data '2024-01-29 ' does not match format '%Y-%m-%d %H:%M'

# %%
'''
This code is working, debugged on classScheduleAll.xlsx
Common errors found were
1. 9:30-10:45  should be 09:30-10:45
2. 9:30- 11:00  one space after - (there should be no space before and after -)
3. Date left as 29th January 2024  29th Jan '24  29-01-2024
4. sheet name program_year_secA/B/C/D   like MBA_01_SECA
   MBADBM_01 (no section fine but program and year should be there)
   IPM_01_SECB   IPM first year section B
'''

from openpyxl import load_workbook
import datetime

class ExcelReader:
    def __init__(self, file_path):
        self.file_path = file_path

    def convert_datetime_format(self,datetime_string):

        try:
             print(datetime_string)
             datetime_object = datetime.datetime.strptime(datetime_string, "%Y-%m-%d %H:%M")
             new_datetime_string = datetime_object.strftime("%d-%m-%Y %H:%M")

             return new_datetime_string
        except Exception as e:
            print(f"Error converting datetime string: {e}")
            return None

    def split_time_slot(self,time_slot):
        parts = time_slot.split(" ")
        dateStr = parts[0].strip()
        startEnd = parts[1].split('-')
        start = startEnd[0]
        end  = startEnd[1]
        startTimeStr = dateStr+ " " + start
        endTimeStr = dateStr + " " + end

        return startTimeStr, endTimeStr



    def read_excel(self):
        """
        Reads an Excel file using openpyxl and prints the data in each sheet.
        """

        # Open the Excel file
        workbook = load_workbook(filename=self.file_path)

        # Iterate through the sheets in the workbook
        for sheet in workbook.worksheets:
            # Print the sheet name
            print(f"Sheet: {sheet.title}")

            # Iterate through the rows in the sheet
            for row_idx,row in enumerate(sheet.rows):
                for col_idx, cell in enumerate(row):
                    #print(row_idx,col_idx)

                    if(row_idx !=0 and col_idx not in [0,1]):
                        if(row_idx % 2 != 0):
                            #print(row_idx,col_idx)
                            courseName=str(cell.value)
                            if (cell.value is None):
                                continue
                            else:
                                timeSlot = str(sheet.cell(row=1, column=(col_idx+1)).value)
                                dateStr = str(sheet.cell(row=(row_idx+1), column=1).value)
                                dateStrS = dateStr[:-9]
                                timeSlotStr =  dateStrS + " " + timeSlot
                                startTimeStr, finishTimeStr = self.split_time_slot(timeSlotStr)
                                startTimeStrC = self.convert_datetime_format(startTimeStr)
                                finishTimeStrC = self.convert_datetime_format(finishTimeStr)
                                #print(timeSlotStr)


                                facultyName = str(sheet.cell(row=row_idx+2,column=col_idx+1).value)
                                ''' Course and Faculty Name can be a list, so need to make a
                                    list of ClassObj
                                '''
                                courseNameL = courseName.split(',')
                                facultyNameL = facultyName.split(',')

                                courseFacultyList = list(zip(courseNameL, facultyNameL))

                                for c,f in courseFacultyList:

                                    courseObjRead = ClassObj(c,f,startTimeStrC, finishTimeStrC,str(sheet.title))
                                    print(courseName,facultyName,startTimeStr, finishTimeStr)
                                    courseObjRead.display()
                                    facultyObj = Faculty(f)
                                    facultyObj.insert_course(courseObjRead)


                print()

# Usage example:
reader = ExcelReader("/content/sample_data/classScheduleAll.xlsx")
reader.read_excel()
# Out:
# Sheet: MBA_02
#
# 2024-01-29 10:30
# 2024-01-29 12:00
# Management Lesson from Geeta Prof. Vittal Rangan 2024-01-29 10:30 2024-01-29 12:00
# Course Name: Management Lesson from Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 29-01-2024 10:30 - 29-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 12:15
# 2024-01-29 13:45
# Retail Marketing Prof. Nanda Choudhary 2024-01-29 12:15 2024-01-29 13:45
# Course Name: Retail Marketing
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 29-01-2024 12:15 - 29-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 14:45
# 2024-01-29 16:15
# Luxury & Fashion Management Prof. Ramesh Roshan Das Guru 2024-01-29 14:45 2024-01-29 16:15
# Course Name: Luxury & Fashion Management
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 29-01-2024 14:45 - 29-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 16:30
# 2024-01-29 18:00
# Cloud Computing Prof. Gaurav Abhishek Tigga 2024-01-29 16:30 2024-01-29 18:00
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 29-01-2024 16:30 - 29-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-29 18:15
# 2024-01-29 19:45
# Marketing Strategy (Sec A) Prof. Satish C Ojha 2024-01-29 18:15 2024-01-29 19:45
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 29-01-2024 18:15 - 29-01-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-01-30 10:30
# 2024-01-30 12:00
# Operations Strategy Prof. Ajith Tom James 2024-01-30 10:30 2024-01-30 12:00
# Course Name: Operations Strategy
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 30-01-2024 10:30 - 30-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 12:15
# 2024-01-30 13:45
# Marketing Strategy (Sec A), Marketing Strategy (Sec B) Prof. Satish C Ojha, Prof. Nanda Choudhary 2024-01-30 12:15 2024-01-30 13:45
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 30-01-2024 12:15 - 30-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Marketing Strategy (Sec A), Marketing Strategy (Sec B) Prof. Satish C Ojha, Prof. Nanda Choudhary 2024-01-30 12:15 2024-01-30 13:45
# Course Name:  Marketing Strategy (Sec B)
# Faculty Name:  Prof. Nanda Choudhary
# Time Slot: 30-01-2024 12:15 - 30-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 14:45
# 2024-01-30 16:15
# Strategic HRM Prof. Remya Latabhavan 2024-01-30 14:45 2024-01-30 16:15
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 30-01-2024 14:45 - 30-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 16:30
# 2024-01-30 18:00
# Strategy & Organizational Leadership Prof. Srividya Raghavan 2024-01-30 16:30 2024-01-30 18:00
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 30-01-2024 16:30 - 30-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-30 18:15
# 2024-01-30 19:45
# International Finance Prof. Molla Ramizur Rahman 2024-01-30 18:15 2024-01-30 19:45
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 30-01-2024 18:15 - 30-01-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-01-31 08:45
# 2024-01-31 10:15
# Cloud Computing Prof. Gaurav Abhishek Tigga 2024-01-31 08:45 2024-01-31 10:15
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 31-01-2024 08:45 - 31-01-2024 10:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 10:30
# 2024-01-31 12:00
# International Finance, Retail Marketing Prof. Molla Ramizur Rahman, Prof. Nanda Choudhary 2024-01-31 10:30 2024-01-31 12:00
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 31-01-2024 10:30 - 31-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# International Finance, Retail Marketing Prof. Molla Ramizur Rahman, Prof. Nanda Choudhary 2024-01-31 10:30 2024-01-31 12:00
# Course Name:  Retail Marketing
# Faculty Name:  Prof. Nanda Choudhary
# Time Slot: 31-01-2024 10:30 - 31-01-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 12:15
# 2024-01-31 13:45
# International Business Prof. Suresh K G 2024-01-31 12:15 2024-01-31 13:45
# Course Name: International Business
# Faculty Name: Prof. Suresh K G
# Time Slot: 31-01-2024 12:15 - 31-01-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 14:45
# 2024-01-31 16:15
# Luxury & Fashion Management Prof. Ramesh Roshan Das Guru 2024-01-31 14:45 2024-01-31 16:15
# Course Name: Luxury & Fashion Management
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 31-01-2024 14:45 - 31-01-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-01-31 16:30
# 2024-01-31 18:00
# Management Lesson from Geeta Prof. Vittal Rangan 2024-01-31 16:30 2024-01-31 18:00
# Course Name: Management Lesson from Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 31-01-2024 16:30 - 31-01-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-02-01 08:45
# 2024-02-01 10:15
# Strategy & Organizational Leadership Prof. Srividya Raghavan 2024-02-01 08:45 2024-02-01 10:15
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 01-02-2024 08:45 - 01-02-2024 10:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-01 14:45
# 2024-02-01 16:15
# Cloud Computing Prof. Gaurav Abhishek Tigga 2024-02-01 14:45 2024-02-01 16:15
# Course Name: Cloud Computing
# Faculty Name: Prof. Gaurav Abhishek Tigga
# Time Slot: 01-02-2024 14:45 - 01-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-01 16:30
# 2024-02-01 18:00
# Strategy & Organizational Leadership Prof. Srividya Raghavan 2024-02-01 16:30 2024-02-01 18:00
# Course Name: Strategy & Organizational Leadership
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 01-02-2024 16:30 - 01-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-01 18:15
# 2024-02-01 19:45
# Operations Strategy Prof. Ajith Tom James 2024-02-01 18:15 2024-02-01 19:45
# Course Name: Operations Strategy
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 01-02-2024 18:15 - 01-02-2024 19:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-02-02 10:30
# 2024-02-02 12:00
# Marketing Strategy (Sec B) Prof. Nanda Choudhary 2024-02-02 10:30 2024-02-02 12:00
# Course Name: Marketing Strategy (Sec B)
# Faculty Name: Prof. Nanda Choudhary
# Time Slot: 02-02-2024 10:30 - 02-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-02 12:15
# 2024-02-02 13:45
# International Business Prof. Suresh K G 2024-02-02 12:15 2024-02-02 13:45
# Course Name: International Business
# Faculty Name: Prof. Suresh K G
# Time Slot: 02-02-2024 12:15 - 02-02-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-02 14:45
# 2024-02-02 16:15
# Strategic HRM Prof. Remya Latabhavan 2024-02-02 14:45 2024-02-02 16:15
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 02-02-2024 14:45 - 02-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-02 16:30
# 2024-02-02 18:00
# Investment Banking Prof. Archana Patro 2024-02-02 16:30 2024-02-02 18:00
# Course Name: Investment Banking
# Faculty Name: Prof. Archana Patro
# Time Slot: 02-02-2024 16:30 - 02-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# 2024-02-03 10:30
# 2024-02-03 12:00
# Marketing Strategy (Sec A), Marketing Strategy (Sec B) Prof. Satish C Ojha, Prof. Nanda Choudhary 2024-02-03 10:30 2024-02-03 12:00
# Course Name: Marketing Strategy (Sec A)
# Faculty Name: Prof. Satish C Ojha
# Time Slot: 03-02-2024 10:30 - 03-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# Marketing Strategy (Sec A), Marketing Strategy (Sec B) Prof. Satish C Ojha, Prof. Nanda Choudhary 2024-02-03 10:30 2024-02-03 12:00
# Course Name:  Marketing Strategy (Sec B)
# Faculty Name:  Prof. Nanda Choudhary
# Time Slot: 03-02-2024 10:30 - 03-02-2024 12:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-03 12:15
# 2024-02-03 13:45
# Investment Banking Guest Session 2024-02-03 12:15 2024-02-03 13:45
# Course Name: Investment Banking
# Faculty Name: Guest Session
# Time Slot: 03-02-2024 12:15 - 03-02-2024 13:45
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-03 14:45
# 2024-02-03 16:15
# International Finance Prof. Molla Ramizur Rahman 2024-02-03 14:45 2024-02-03 16:15
# Course Name: International Finance
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 03-02-2024 14:45 - 03-02-2024 16:15
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
# 2024-02-03 16:30
# 2024-02-03 18:00
# Strategic HRM Prof. Remya Latabhavan 2024-02-03 16:30 2024-02-03 18:00
# Course Name: Strategic HRM
# Faculty Name: Prof. Remya Latabhavan
# Time Slot: 03-02-2024 16:30 - 03-02-2024 18:00
# Program Name: MBA_02
# Program: MBA
# Year: 02
# Section: None
#
#
# Sheet: MBA_01_SECA
#
# 2024-01-29 11:15
# 2024-01-29 12:45
# 6:Financial Management II Prof. Ashish Sharma 2024-01-29 11:15 2024-01-29 12:45
# Course Name: 6:Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 29-01-2024 11:15 - 29-01-2024 12:45
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-01-29 15:30
# 2024-01-29 17:00
# Econometric Analysis for Business Management Prof. Thasni T 2024-01-29 15:30 2024-01-29 17:00
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Thasni T
# Time Slot: 29-01-2024 15:30 - 29-01-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-01-29 17:00
# 2024-01-29 18:30
# Business Data Analytics Prof. Manali Chatterjee 2024-01-29 17:00 2024-01-29 18:30
# Course Name: Business Data Analytics
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 29-01-2024 17:00 - 29-01-2024 18:30
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# 2024-01-30 09:30
# 2024-01-30 11:00
# Business Research Methodology Prof. Sk Abu Khalek 2024-01-30 09:30 2024-01-30 11:00
# Course Name: Business Research Methodology
# Faculty Name: Prof. Sk Abu Khalek
# Time Slot: 30-01-2024 09:30 - 30-01-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-01-30 11:15
# 2024-01-30 12:45
# Strategic Management Prof. Amit Srivastava 2024-01-30 11:15 2024-01-30 12:45
# Course Name: Strategic Management
# Faculty Name: Prof. Amit Srivastava
# Time Slot: 30-01-2024 11:15 - 30-01-2024 12:45
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-01-30 15:30
# 2024-01-30 17:00
# Indian Legal System Prof. Soumya Prakash Patra 2024-01-30 15:30 2024-01-30 17:00
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 30-01-2024 15:30 - 30-01-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# 2024-01-31 09:30
# 2024-01-31 11:00
# Business Data Analytics Prof. Manali Chatterjee 2024-01-31 09:30 2024-01-31 11:00
# Course Name: Business Data Analytics
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 31-01-2024 09:30 - 31-01-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-01-31 11:15
# 2024-01-31 12:45
# Econometric Analysis for Business Management Prof. Thasni T 2024-01-31 11:15 2024-01-31 12:45
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Thasni T
# Time Slot: 31-01-2024 11:15 - 31-01-2024 12:45
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# 2024-02-01 09:30
# 2024-02-01 11:00
# Business Research Methodology Prof. Sk Abu Khalek 2024-02-01 09:30 2024-02-01 11:00
# Course Name: Business Research Methodology
# Faculty Name: Prof. Sk Abu Khalek
# Time Slot: 01-02-2024 09:30 - 01-02-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-02-01 15:30
# 2024-02-01 17:00
# Strategic Management Prof. Amit Srivastava 2024-02-01 15:30 2024-02-01 17:00
# Course Name: Strategic Management
# Faculty Name: Prof. Amit Srivastava
# Time Slot: 01-02-2024 15:30 - 01-02-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
# 2024-02-02 09:30
# 2024-02-02 11:00
# Operation Management Prof. Chiranjit Das 2024-02-02 09:30 2024-02-02 11:00
# Course Name: Operation Management
# Faculty Name: Prof. Chiranjit Das
# Time Slot: 02-02-2024 09:30 - 02-02-2024 11:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
# 2024-02-02 15:30
# 2024-02-02 17:00
# Marketing Management III Prof. Satish C. Ojha 2024-02-02 15:30 2024-02-02 17:00
# Course Name: Marketing Management III
# Faculty Name: Prof. Satish C. Ojha
# Time Slot: 02-02-2024 15:30 - 02-02-2024 17:00
# Program Name: MBA_01_SECA
# Program: MBA
# Year: 01
# Section: SECA
#
#
#
#
#
# Sheet: MBA_01_SECB
#
# 2024-01-29 11:15
# 2024-01-29 12:45
# Econometric Analysis for Business Management Prof. Suresh KG 2024-01-29 11:15 2024-01-29 12:45
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Suresh KG
# Time Slot: 29-01-2024 11:15 - 29-01-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-01-29 15:30
# 2024-01-29 17:00
# Business Data Analytics Prof. Supriya Ghatak 2024-01-29 15:30 2024-01-29 17:00
# Course Name: Business Data Analytics
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 29-01-2024 15:30 - 29-01-2024 17:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-01-29 17:00
# 2024-01-29 18:30
# Financial Management II Prof. Ashish Sharma 2024-01-29 17:00 2024-01-29 18:30
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 29-01-2024 17:00 - 29-01-2024 18:30
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# 2024-01-30 09:30
# 2024-01-30 11:00
# Indian Legal System Prof. Soumya Prakash Patra 2024-01-30 09:30 2024-01-30 11:00
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 30-01-2024 09:30 - 30-01-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-01-30 11:15
# 2024-01-30 12:45
# Business Research Methodology Prof. Amresh Kumar 2024-01-30 11:15 2024-01-30 12:45
# Course Name: Business Research Methodology
# Faculty Name: Prof. Amresh Kumar
# Time Slot: 30-01-2024 11:15 - 30-01-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-01-30 15:30
# 2024-01-30 17:00
# Operation Management Prof. Rohit Agarwal 2024-01-30 15:30 2024-01-30 17:00
# Course Name: Operation Management
# Faculty Name: Prof. Rohit Agarwal
# Time Slot: 30-01-2024 15:30 - 30-01-2024 17:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# 2024-01-31 09:30
# 2024-01-31 11:00
# Marketing Management III Prof. Aditi Sharma 2024-01-31 09:30 2024-01-31 11:00
# Course Name: Marketing Management III
# Faculty Name: Prof. Aditi Sharma
# Time Slot: 31-01-2024 09:30 - 31-01-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-01-31 11:15
# 2024-01-31 12:45
# Business Data Analytics Prof. Supriya Ghatak 2024-01-31 11:15 2024-01-31 12:45
# Course Name: Business Data Analytics
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 31-01-2024 11:15 - 31-01-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# 2024-02-01 09:30
# 2024-02-01 11:00
# Indian Legal System Prof. Soumya Prakash Patra 2024-02-01 09:30 2024-02-01 11:00
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 01-02-2024 09:30 - 01-02-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-02-01 15:30
# 2024-02-01 17:00
# Business Research Methodology Prof. Amresh Kumar 2024-02-01 15:30 2024-02-01 17:00
# Course Name: Business Research Methodology
# Faculty Name: Prof. Amresh Kumar
# Time Slot: 01-02-2024 15:30 - 01-02-2024 17:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
# 2024-02-02 09:30
# 2024-02-02 11:00
# Financial Management II Prof. Ashish Sharma 2024-02-02 09:30 2024-02-02 11:00
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 02-02-2024 09:30 - 02-02-2024 11:00
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
# 2024-02-02 11:15
# 2024-02-02 12:45
# Operation Management Prof. Rohit Agarwal 2024-02-02 11:15 2024-02-02 12:45
# Course Name: Operation Management
# Faculty Name: Prof. Rohit Agarwal
# Time Slot: 02-02-2024 11:15 - 02-02-2024 12:45
# Program Name: MBA_01_SECB
# Program: MBA
# Year: 01
# Section: SECB
#
#
#
#
# Sheet: MBA_01_SECC
#
# 2024-01-29 11:15
# 2024-01-29 12:45
# Business Data Analytics Prof. Gaurav Tigga  2024-01-29 11:15 2024-01-29 12:45
# Course Name: Business Data Analytics
# Faculty Name: Prof. Gaurav Tigga
# Time Slot: 29-01-2024 11:15 - 29-01-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-01-29 15:30
# 2024-01-29 17:00
# Financial Management II Prof. Ashish Sharma 2024-01-29 15:30 2024-01-29 17:00
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 29-01-2024 15:30 - 29-01-2024 17:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-01-29 17:00
# 2024-01-29 18:30
# Econometric Analysis for Business Management Prof. Aviral K Tiwary 2024-01-29 17:00 2024-01-29 18:30
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Aviral K Tiwary
# Time Slot: 29-01-2024 17:00 - 29-01-2024 18:30
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# 2024-01-30 09:30
# 2024-01-30 11:00
# Strategic Management Prof. Atma Prakash Ojha 2024-01-30 09:30 2024-01-30 11:00
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 30-01-2024 09:30 - 30-01-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-01-30 11:15
# 2024-01-30 12:45
# Operation Management Prof. Shashank Kumar 2024-01-30 11:15 2024-01-30 12:45
# Course Name: Operation Management
# Faculty Name: Prof. Shashank Kumar
# Time Slot: 30-01-2024 11:15 - 30-01-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-01-30 15:30
# 2024-01-30 17:00
# Business Research Methodology Prof. Chandan Parsad 2024-01-30 15:30 2024-01-30 17:00
# Course Name: Business Research Methodology
# Faculty Name: Prof. Chandan Parsad
# Time Slot: 30-01-2024 15:30 - 30-01-2024 17:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# 2024-01-31 09:30
# 2024-01-31 11:00
# Econometric Analysis for Business Management Prof. Aviral K Tiwary 2024-01-31 09:30 2024-01-31 11:00
# Course Name: Econometric Analysis for Business Management
# Faculty Name: Prof. Aviral K Tiwary
# Time Slot: 31-01-2024 09:30 - 31-01-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-01-31 11:15
# 2024-01-31 12:45
# Marketing Management III Prof. Satish C. Ojha 2024-01-31 11:15 2024-01-31 12:45
# Course Name: Marketing Management III
# Faculty Name: Prof. Satish C. Ojha
# Time Slot: 31-01-2024 11:15 - 31-01-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# 2024-02-01 09:30
# 2024-02-01 11:00
# Strategic Management Prof. Atma Prakash Ojha 2024-02-01 09:30 2024-02-01 11:00
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 01-02-2024 09:30 - 01-02-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-02-01 15:30
# 2024-02-01 17:00
# Indian Legal System Prof. Soumya Prakash Patra 2024-02-01 15:30 2024-02-01 17:00
# Course Name: Indian Legal System
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 01-02-2024 15:30 - 01-02-2024 17:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
# 2024-02-02 09:30
# 2024-02-02 11:00
# Operation Management Prof. Shashank Kumar 2024-02-02 09:30 2024-02-02 11:00
# Course Name: Operation Management
# Faculty Name: Prof. Shashank Kumar
# Time Slot: 02-02-2024 09:30 - 02-02-2024 11:00
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
# 2024-02-02 11:15
# 2024-02-02 12:45
# Financial Management II Prof. Ashish Sharma 2024-02-02 11:15 2024-02-02 12:45
# Course Name: Financial Management II
# Faculty Name: Prof. Ashish Sharma
# Time Slot: 02-02-2024 11:15 - 02-02-2024 12:45
# Program Name: MBA_01_SECC
# Program: MBA
# Year: 01
# Section: SECC
#
#
#
#
# Sheet: MBADBM_01
#
# 2024-01-29 10:45
# 2024-01-29 12:15
# Project Management in Digital Business Prof. Ajith Tom James 2024-01-29 10:45 2024-01-29 12:15
# Course Name: Project Management in Digital Business
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 29-01-2024 10:45 - 29-01-2024 12:15
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-01-29 13:15
# 2024-01-29 14:45
# Analytics in Modern Business Prof. Madanlal Yadav 2024-01-29 13:15 2024-01-29 14:45
# Course Name: Analytics in Modern Business
# Faculty Name: Prof. Madanlal Yadav
# Time Slot: 29-01-2024 13:15 - 29-01-2024 14:45
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
#
#
# 2024-01-30 09:00
# 2024-01-30 10:30
# Critical Thinking and Problem Solving for Enabling Digital Business Prof. Srividya R 2024-01-30 09:00 2024-01-30 10:30
# Course Name: Critical Thinking and Problem Solving for Enabling Digital Business
# Faculty Name: Prof. Srividya R
# Time Slot: 30-01-2024 09:00 - 30-01-2024 10:30
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-01-30 10:45
# 2024-01-30 12:15
# Corporate Cost Control Prof. Molla Ramizur Rahman 2024-01-30 10:45 2024-01-30 12:15
# Course Name: Corporate Cost Control
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 30-01-2024 10:45 - 30-01-2024 12:15
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-01-30 13:15
# 2024-01-30 14:45
# Digital Marketing Prof. Amresh Kumar 2024-01-30 13:15 2024-01-30 14:45
# Course Name: Digital Marketing
# Faculty Name: Prof. Amresh Kumar
# Time Slot: 30-01-2024 13:15 - 30-01-2024 14:45
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
#
#
# 2024-01-31 09:00
# 2024-01-31 10:30
# Analytics in Modern Business Prof. Madanlal Yadav 2024-01-31 09:00 2024-01-31 10:30
# Course Name: Analytics in Modern Business
# Faculty Name: Prof. Madanlal Yadav
# Time Slot: 31-01-2024 09:00 - 31-01-2024 10:30
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-01-31 10:45
# 2024-01-31 12:15
# Analytics in Modern Business Prof. Madanlal Yadav 2024-01-31 10:45 2024-01-31 12:15
# Course Name: Analytics in Modern Business
# Faculty Name: Prof. Madanlal Yadav
# Time Slot: 31-01-2024 10:45 - 31-01-2024 12:15
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-01-31 13:15
# 2024-01-31 14:45
# Project Management in Digital Business Prof. Ajith Tom James 2024-01-31 13:15 2024-01-31 14:45
# Course Name: Project Management in Digital Business
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 31-01-2024 13:15 - 31-01-2024 14:45
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-01-31 15:00
# 2024-01-31 16:30
# Corporate Cost Control Prof. Molla Ramizur Rahman 2024-01-31 15:00 2024-01-31 16:30
# Course Name: Corporate Cost Control
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 31-01-2024 15:00 - 31-01-2024 16:30
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
#
#
# 2024-02-01 09:00
# 2024-02-01 10:30
# Critical Thinking and Problem Solving for Enabling Digital Business Prof. Srividya R 2024-02-01 09:00 2024-02-01 10:30
# Course Name: Critical Thinking and Problem Solving for Enabling Digital Business
# Faculty Name: Prof. Srividya R
# Time Slot: 01-02-2024 09:00 - 01-02-2024 10:30
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-02-01 10:45
# 2024-02-01 12:15
# Corporate Cost Control Prof. Molla Ramizur Rahman 2024-02-01 10:45 2024-02-01 12:15
# Course Name: Corporate Cost Control
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 01-02-2024 10:45 - 01-02-2024 12:15
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
# 2024-02-01 13:15
# 2024-02-01 14:45
# Digital Marketing Prof. Amresh Kumar 2024-02-01 13:15 2024-02-01 14:45
# Course Name: Digital Marketing
# Faculty Name: Prof. Amresh Kumar
# Time Slot: 01-02-2024 13:15 - 01-02-2024 14:45
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
#
#
# 2024-02-02 10:45
# 2024-02-02 12:15
# Corporate Cost Control Prof. Molla Ramizur Rahman 2024-02-02 10:45 2024-02-02 12:15
# Course Name: Corporate Cost Control
# Faculty Name: Prof. Molla Ramizur Rahman
# Time Slot: 02-02-2024 10:45 - 02-02-2024 12:15
# Program Name: MBADBM_01
# Program: MBADBM
# Year: 01
# Section: None
#
#
#
#
# Sheet: MBADBM_02
# Sheet: MBAHHM_01
#
# 2024-01-29 10:45
# 2024-01-29 12:15
# Research Methodology for Healthcare Prof. Raghunathan Krishnakumar 2024-01-29 10:45 2024-01-29 12:15
# Course Name: Research Methodology for Healthcare
# Faculty Name: Prof. Raghunathan Krishnakumar
# Time Slot: 29-01-2024 10:45 - 29-01-2024 12:15
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# 2024-01-29 13:15
# 2024-01-29 14:45
# Service Leadership in Healthcare Prof. Teena Bharti 2024-01-29 13:15 2024-01-29 14:45
# Course Name: Service Leadership in Healthcare
# Faculty Name: Prof. Teena Bharti
# Time Slot: 29-01-2024 13:15 - 29-01-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# 2024-01-29 15:00
# 2024-01-29 16:30
# Strategic Management Prof. Atma Prakash Ojha 2024-01-29 15:00 2024-01-29 16:30
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 29-01-2024 15:00 - 29-01-2024 16:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# 2024-01-30 09:00
# 2024-01-30 10:30
# Digital Transformation for Healthcare Prof. Manali Chatterjee 2024-01-30 09:00 2024-01-30 10:30
# Course Name: Digital Transformation for Healthcare
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 30-01-2024 09:00 - 30-01-2024 10:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# 2024-01-30 13:15
# 2024-01-30 14:45
# Entrepreneurship & New Venture Planning for Healthcare Prof. Atma Prakash Ojha 2024-01-30 13:15 2024-01-30 14:45
# Course Name: Entrepreneurship & New Venture Planning for Healthcare
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 30-01-2024 13:15 - 30-01-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# 2024-01-31 10:45
# 2024-01-31 12:15
# Research Methodology for Healthcare Prof. Raghunathan Krishnakumar 2024-01-31 10:45 2024-01-31 12:15
# Course Name: Research Methodology for Healthcare
# Faculty Name: Prof. Raghunathan Krishnakumar
# Time Slot: 31-01-2024 10:45 - 31-01-2024 12:15
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# 2024-01-31 13:15
# 2024-01-31 14:45
# Strategic Management Prof. Atma Prakash Ojha 2024-01-31 13:15 2024-01-31 14:45
# Course Name: Strategic Management
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 31-01-2024 13:15 - 31-01-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# 2024-01-31 15:00
# 2024-01-31 16:30
# Service Leadership in Healthcare Prof. Teena Bharti 2024-01-31 15:00 2024-01-31 16:30
# Course Name: Service Leadership in Healthcare
# Faculty Name: Prof. Teena Bharti
# Time Slot: 31-01-2024 15:00 - 31-01-2024 16:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# 2024-02-01 09:00
# 2024-02-01 10:30
# Digital Transformation for Healthcare Prof. Manali Chatterjee 2024-02-01 09:00 2024-02-01 10:30
# Course Name: Digital Transformation for Healthcare
# Faculty Name: Prof. Manali Chatterjee
# Time Slot: 01-02-2024 09:00 - 01-02-2024 10:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
# 2024-02-02 13:15
# 2024-02-02 14:45
# Entrepreneurship & New Venture Planning for Healthcare Prof. Atma Prakash Ojha 2024-02-02 13:15 2024-02-02 14:45
# Course Name: Entrepreneurship & New Venture Planning for Healthcare
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 02-02-2024 13:15 - 02-02-2024 14:45
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
# 2024-02-02 15:00
# 2024-02-02 16:30
# Service Leadership in Healthcare Prof. Teena Bharti 2024-02-02 15:00 2024-02-02 16:30
# Course Name: Service Leadership in Healthcare
# Faculty Name: Prof. Teena Bharti
# Time Slot: 02-02-2024 15:00 - 02-02-2024 16:30
# Program Name: MBAHHM_01
# Program: MBAHHM
# Year: 01
# Section: None
#
#
#
# Sheet: MBAHHM_02
# Sheet: IPM_01_SECA
#
# 2024-01-29 08:30
# 2024-01-29 9:30
# World Business History Prof. Abhishek Yadav 2024-01-29 08:30 2024-01-29 9:30
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 29-01-2024 08:30 - 29-01-2024 09:30
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-29 09:45
# 2024-01-29 10:45
# The Science of Well-Being Prof. Suman Choudhary 2024-01-29 09:45 2024-01-29 10:45
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 29-01-2024 09:45 - 29-01-2024 10:45
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-29 11:00
# 2024-01-29 12:00
# Critical Thinking & Writing Skills - I Prof. Gargi Roy 2024-01-29 11:00 2024-01-29 12:00
# Course Name: Critical Thinking & Writing Skills - I
# Faculty Name: Prof. Gargi Roy
# Time Slot: 29-01-2024 11:00 - 29-01-2024 12:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-29 13:00
# 2024-01-29 14:00
# Introduction to Psychology Prof. Prabhu G 2024-01-29 13:00 2024-01-29 14:00
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 29-01-2024 13:00 - 29-01-2024 14:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-29 14:15
# 2024-01-29 15:15
# Presentation Skills Workshop Prof. Sanjay Kaushal 2024-01-29 14:15 2024-01-29 15:15
# Course Name: Presentation Skills Workshop
# Faculty Name: Prof. Sanjay Kaushal
# Time Slot: 29-01-2024 14:15 - 29-01-2024 15:15
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
#
#
# 2024-01-30 08:30
# 2024-01-30 9:30
# The Science of Well-Being Prof. Suman Choudhary 2024-01-30 08:30 2024-01-30 9:30
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 30-01-2024 08:30 - 30-01-2024 09:30
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-30 09:45
# 2024-01-30 10:45
# Introduction to Cost &  Management  Accounting Prof. Bharati Singh 2024-01-30 09:45 2024-01-30 10:45
# Course Name: Introduction to Cost &  Management  Accounting
# Faculty Name: Prof. Bharati Singh
# Time Slot: 30-01-2024 09:45 - 30-01-2024 10:45
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-30 11:00
# 2024-01-30 12:00
# World Business History Prof. Abhishek Yadav 2024-01-30 11:00 2024-01-30 12:00
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 30-01-2024 11:00 - 30-01-2024 12:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-30 13:00
# 2024-01-30 14:00
# Indian Heritage & Culture Prof. Vttal Rangan 2024-01-30 13:00 2024-01-30 14:00
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 30-01-2024 13:00 - 30-01-2024 14:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
#
#
# 2024-01-31 08:30
# 2024-01-31 9:30
# Managerial Economics II Prof. Thasni T 2024-01-31 08:30 2024-01-31 9:30
# Course Name: Managerial Economics II
# Faculty Name: Prof. Thasni T
# Time Slot: 31-01-2024 08:30 - 31-01-2024 09:30
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-31 09:45
# 2024-01-31 10:45
# Critical Thinking & Writing Skills - I Prof. Gargi Roy 2024-01-31 09:45 2024-01-31 10:45
# Course Name: Critical Thinking & Writing Skills - I
# Faculty Name: Prof. Gargi Roy
# Time Slot: 31-01-2024 09:45 - 31-01-2024 10:45
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-31 11:00
# 2024-01-31 12:00
# World Business History Prof. Abhishek Yadav 2024-01-31 11:00 2024-01-31 12:00
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 31-01-2024 11:00 - 31-01-2024 12:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-31 13:00
# 2024-01-31 14:00
# Business & Company Law Prof. Soumya Prakash Patra 2024-01-31 13:00 2024-01-31 14:00
# Course Name: Business & Company Law
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 31-01-2024 13:00 - 31-01-2024 14:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-01-31 14:15
# 2024-01-31 15:15
# Introduction to Psychology Prof. Prabhu G 2024-01-31 14:15 2024-01-31 15:15
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 31-01-2024 14:15 - 31-01-2024 15:15
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
#
#
# 2024-02-01 09:45
# 2024-02-01 10:45
# The Science of Well-Being Prof. Suman Choudhary 2024-02-01 09:45 2024-02-01 10:45
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 01-02-2024 09:45 - 01-02-2024 10:45
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-01 11:00
# 2024-02-01 12:00
# World Business History Prof. Abhishek Yadav 2024-02-01 11:00 2024-02-01 12:00
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 01-02-2024 11:00 - 01-02-2024 12:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-01 13:00
# 2024-02-01 14:00
# Indian Heritage & Culture Prof. Vttal Rangan 2024-02-01 13:00 2024-02-01 14:00
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 01-02-2024 13:00 - 01-02-2024 14:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-01 14:15
# 2024-02-01 15:15
# Introduction to Psychology Prof. Prabhu G 2024-02-01 14:15 2024-02-01 15:15
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 01-02-2024 14:15 - 01-02-2024 15:15
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
#
#
# 2024-02-02 08:30
# 2024-02-02 9:30
# Managerial Economics II Prof. Thasni T 2024-02-02 08:30 2024-02-02 9:30
# Course Name: Managerial Economics II
# Faculty Name: Prof. Thasni T
# Time Slot: 02-02-2024 08:30 - 02-02-2024 09:30
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-02 09:45
# 2024-02-02 10:45
# Business & Company Law Prof. Soumya Prakash Patra 2024-02-02 09:45 2024-02-02 10:45
# Course Name: Business & Company Law
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 02-02-2024 09:45 - 02-02-2024 10:45
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-02 11:00
# 2024-02-02 12:00
# Introduction to Psychology Prof. Prabhu G 2024-02-02 11:00 2024-02-02 12:00
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 02-02-2024 11:00 - 02-02-2024 12:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-02 13:00
# 2024-02-02 14:00
# The Science of Well-Being Prof. Suman Choudhary 2024-02-02 13:00 2024-02-02 14:00
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 02-02-2024 13:00 - 02-02-2024 14:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-02 14:15
# 2024-02-02 15:15
# Indian Heritage & Culture Prof. Vttal Rangan 2024-02-02 14:15 2024-02-02 15:15
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 02-02-2024 14:15 - 02-02-2024 15:15
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
#
#
# 2024-02-03 09:45
# 2024-02-03 10:45
# Introduction to Psychology Prof. Prabhu G 2024-02-03 09:45 2024-02-03 10:45
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 03-02-2024 09:45 - 03-02-2024 10:45
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-03 11:00
# 2024-02-03 12:00
# World Business History Prof. Abhishek Yadav 2024-02-03 11:00 2024-02-03 12:00
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 03-02-2024 11:00 - 03-02-2024 12:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-03 13:00
# 2024-02-03 14:00
# Presentation Skills Workshop Prof. Sanjay Kaushal 2024-02-03 13:00 2024-02-03 14:00
# Course Name: Presentation Skills Workshop
# Faculty Name: Prof. Sanjay Kaushal
# Time Slot: 03-02-2024 13:00 - 03-02-2024 14:00
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
# 2024-02-03 14:15
# 2024-02-03 15:15
# Indian Heritage & Culture Prof. Vttal Rangan 2024-02-03 14:15 2024-02-03 15:15
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 03-02-2024 14:15 - 03-02-2024 15:15
# Program Name: IPM_01_SECA
# Program: IPM
# Year: 01
# Section: SECA
#
#
#
# Sheet: IPM_01_SECB
#
# 2024-01-29 09:45
# 2024-01-29 10:45
# World Business History Prof. Abhishek Yadav 2024-01-29 09:45 2024-01-29 10:45
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 29-01-2024 09:45 - 29-01-2024 10:45
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-29 11:00
# 2024-01-29 12:00
# The Science of Well-Being Prof. Suman Choudhary 2024-01-29 11:00 2024-01-29 12:00
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 29-01-2024 11:00 - 29-01-2024 12:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-29 13:00
# 2024-01-29 14:00
# Critical Thinking & Writing Skills - I Prof. Urjani Chakravarty 2024-01-29 13:00 2024-01-29 14:00
# Course Name: Critical Thinking & Writing Skills - I
# Faculty Name: Prof. Urjani Chakravarty
# Time Slot: 29-01-2024 13:00 - 29-01-2024 14:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-29 14:15
# 2024-01-29 15:15
# Introduction to Psychology Prof. Prabhu G 2024-01-29 14:15 2024-01-29 15:15
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 29-01-2024 14:15 - 29-01-2024 15:15
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
#
#
# 2024-01-30 08:30
# 2024-01-30 09:30
# Introduction to Cost &  Management  Accounting Prof. Bharati Singh 2024-01-30 08:30 2024-01-30 09:30
# Course Name: Introduction to Cost &  Management  Accounting
# Faculty Name: Prof. Bharati Singh
# Time Slot: 30-01-2024 08:30 - 30-01-2024 09:30
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-30 09:45
# 2024-01-30 10:45
# The Science of Well-Being Prof. Suman Choudhary 2024-01-30 09:45 2024-01-30 10:45
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 30-01-2024 09:45 - 30-01-2024 10:45
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-30 11:00
# 2024-01-30 12:00
# Indian Heritage & Culture Prof. Vttal Rangan 2024-01-30 11:00 2024-01-30 12:00
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 30-01-2024 11:00 - 30-01-2024 12:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-30 13:00
# 2024-01-30 14:00
# Critical Thinking & Writing Skills - I Prof. Urjani Chakravarty 2024-01-30 13:00 2024-01-30 14:00
# Course Name: Critical Thinking & Writing Skills - I
# Faculty Name: Prof. Urjani Chakravarty
# Time Slot: 30-01-2024 13:00 - 30-01-2024 14:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-30 14:15
# 2024-01-30 15:15
# World Business History Prof. Abhishek Yadav 2024-01-30 14:15 2024-01-30 15:15
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 30-01-2024 14:15 - 30-01-2024 15:15
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
#
#
# 2024-01-31 08:30
# 2024-01-31 09:30
# World Business History Prof. Abhishek Yadav 2024-01-31 08:30 2024-01-31 09:30
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 31-01-2024 08:30 - 31-01-2024 09:30
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-31 09:45
# 2024-01-31 10:45
# Spread Sheet Modelling Prof. Madanlal Yadav 2024-01-31 09:45 2024-01-31 10:45
# Course Name: Spread Sheet Modelling
# Faculty Name: Prof. Madanlal Yadav
# Time Slot: 31-01-2024 09:45 - 31-01-2024 10:45
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-31 11:00
# 2024-01-31 12:00
# Spread Sheet Modelling Prof. Madanlal Yadav 2024-01-31 11:00 2024-01-31 12:00
# Course Name: Spread Sheet Modelling
# Faculty Name: Prof. Madanlal Yadav
# Time Slot: 31-01-2024 11:00 - 31-01-2024 12:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-31 13:00
# 2024-01-31 14:00
# Introduction to Psychology Prof. Prabhu G 2024-01-31 13:00 2024-01-31 14:00
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 31-01-2024 13:00 - 31-01-2024 14:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-01-31 14:15
# 2024-01-31 15:15
# Business & Company Law Prof. Soumya Prakash Patra 2024-01-31 14:15 2024-01-31 15:15
# Course Name: Business & Company Law
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 31-01-2024 14:15 - 31-01-2024 15:15
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
#
#
# 2024-02-01 08:30
# 2024-02-01 09:30
# World Business History Prof. Abhishek Yadav 2024-02-01 08:30 2024-02-01 09:30
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 01-02-2024 08:30 - 01-02-2024 09:30
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-01 09:45
# 2024-02-01 10:45
# Critical Thinking & Writing Skills - I Prof. Urjani Chakravarty 2024-02-01 09:45 2024-02-01 10:45
# Course Name: Critical Thinking & Writing Skills - I
# Faculty Name: Prof. Urjani Chakravarty
# Time Slot: 01-02-2024 09:45 - 01-02-2024 10:45
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-01 11:00
# 2024-02-01 12:00
# The Science of Well-Being Prof. Suman Choudhary 2024-02-01 11:00 2024-02-01 12:00
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 01-02-2024 11:00 - 01-02-2024 12:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-01 13:00
# 2024-02-01 14:00
# Introduction to Psychology Prof. Prabhu G 2024-02-01 13:00 2024-02-01 14:00
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 01-02-2024 13:00 - 01-02-2024 14:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-01 14:15
# 2024-02-01 15:15
# Indian Heritage & Culture Prof. Vttal Rangan 2024-02-01 14:15 2024-02-01 15:15
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 01-02-2024 14:15 - 01-02-2024 15:15
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
#
#
# 2024-02-02 08:30
# 2024-02-02 09:30
# Business & Company Law Prof. Soumya Prakash Patra 2024-02-02 08:30 2024-02-02 09:30
# Course Name: Business & Company Law
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 02-02-2024 08:30 - 02-02-2024 09:30
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-02 09:45
# 2024-02-02 10:45
# Introduction to Psychology Prof. Prabhu G 2024-02-02 09:45 2024-02-02 10:45
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 02-02-2024 09:45 - 02-02-2024 10:45
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-02 11:00
# 2024-02-02 12:00
# Critical Thinking & Writing Skills - I Prof. Urjani Chakravarty 2024-02-02 11:00 2024-02-02 12:00
# Course Name: Critical Thinking & Writing Skills - I
# Faculty Name: Prof. Urjani Chakravarty
# Time Slot: 02-02-2024 11:00 - 02-02-2024 12:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-02 13:00
# 2024-02-02 14:00
# Indian Heritage & Culture Prof. Vttal Rangan 2024-02-02 13:00 2024-02-02 14:00
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 02-02-2024 13:00 - 02-02-2024 14:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-02 14:15
# 2024-02-02 15:15
# The Science of Well-Being Prof. Suman Choudhary 2024-02-02 14:15 2024-02-02 15:15
# Course Name: The Science of Well-Being
# Faculty Name: Prof. Suman Choudhary
# Time Slot: 02-02-2024 14:15 - 02-02-2024 15:15
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
#
#
# 2024-02-03 08:30
# 2024-02-03 09:30
# Presentation Skills Workshop Prof. Gargi Roy 2024-02-03 08:30 2024-02-03 09:30
# Course Name: Presentation Skills Workshop
# Faculty Name: Prof. Gargi Roy
# Time Slot: 03-02-2024 08:30 - 03-02-2024 09:30
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-03 09:45
# 2024-02-03 10:45
# World Business History Prof. Abhishek Yadav 2024-02-03 09:45 2024-02-03 10:45
# Course Name: World Business History
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 03-02-2024 09:45 - 03-02-2024 10:45
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-03 11:00
# 2024-02-03 12:00
# Introduction to Psychology Prof. Prabhu G 2024-02-03 11:00 2024-02-03 12:00
# Course Name: Introduction to Psychology
# Faculty Name: Prof. Prabhu G
# Time Slot: 03-02-2024 11:00 - 03-02-2024 12:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-03 13:00
# 2024-02-03 14:00
# Indian Heritage & Culture Prof. Vttal Rangan 2024-02-03 13:00 2024-02-03 14:00
# Course Name: Indian Heritage & Culture
# Faculty Name: Prof. Vttal Rangan
# Time Slot: 03-02-2024 13:00 - 03-02-2024 14:00
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
# 2024-02-03 14:15
# 2024-02-03 15:15
# Spread Sheet Modelling Prof. Madanlal Yadav 2024-02-03 14:15 2024-02-03 15:15
# Course Name: Spread Sheet Modelling
# Faculty Name: Prof. Madanlal Yadav
# Time Slot: 03-02-2024 14:15 - 03-02-2024 15:15
# Program Name: IPM_01_SECB
# Program: IPM
# Year: 01
# Section: SECB
#
#
#
# Sheet: IPM_02_SECA
#
# 2024-01-29 10:15
# 2024-01-29 11:15
# Operations Management Prof. Vishal Ashok Wankhede 2024-01-29 10:15 2024-01-29 11:15
# Course Name: Operations Management
# Faculty Name: Prof. Vishal Ashok Wankhede
# Time Slot: 29-01-2024 10:15 - 29-01-2024 11:15
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-01-29 11:30
# 2024-01-29 12:30
# Business Research Method Prof. Navin Kumar 2024-01-29 11:30 2024-01-29 12:30
# Course Name: Business Research Method
# Faculty Name: Prof. Navin Kumar
# Time Slot: 29-01-2024 11:30 - 29-01-2024 12:30
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-01-29 13:30
# 2024-01-29 14:30
# Advance Communication Skill Prof. Gargi Roy 2024-01-29 13:30 2024-01-29 14:30
# Course Name: Advance Communication Skill
# Faculty Name: Prof. Gargi Roy
# Time Slot: 29-01-2024 13:30 - 29-01-2024 14:30
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
#
#
# 2024-01-30 09:00
# 2024-01-30 10:00
# Foreign Language II Prof. Durba Banerjee 2024-01-30 09:00 2024-01-30 10:00
# Course Name: Foreign Language II
# Faculty Name: Prof. Durba Banerjee
# Time Slot: 30-01-2024 09:00 - 30-01-2024 10:00
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-01-30 13:30
# 2024-01-30 14:30
# Database Management System Prof. Supriya Ghatak 2024-01-30 13:30 2024-01-30 14:30
# Course Name: Database Management System
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 30-01-2024 13:30 - 30-01-2024 14:30
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
#
#
# 2024-01-31 10:15
# 2024-01-31 11:15
# Critical Thinking & Writing Skills II Prof. Urjani Chakravarti 2024-01-31 10:15 2024-01-31 11:15
# Course Name: Critical Thinking & Writing Skills II
# Faculty Name: Prof. Urjani Chakravarti
# Time Slot: 31-01-2024 10:15 - 31-01-2024 11:15
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-01-31 13:30
# 2024-01-31 14:30
# Business Research Method Prof. Navin Kumar 2024-01-31 13:30 2024-01-31 14:30
# Course Name: Business Research Method
# Faculty Name: Prof. Navin Kumar
# Time Slot: 31-01-2024 13:30 - 31-01-2024 14:30
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-01-31 14:45
# 2024-01-31 15:45
# Advance Communication Skill Prof. Gargi Roy 2024-01-31 14:45 2024-01-31 15:45
# Course Name: Advance Communication Skill
# Faculty Name: Prof. Gargi Roy
# Time Slot: 31-01-2024 14:45 - 31-01-2024 15:45
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
#
#
# 2024-02-01 11:30
# 2024-02-01 12:30
# Foreign Language II Prof. Durba Banerjee 2024-02-01 11:30 2024-02-01 12:30
# Course Name: Foreign Language II
# Faculty Name: Prof. Durba Banerjee
# Time Slot: 01-02-2024 11:30 - 01-02-2024 12:30
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-02-01 13:30
# 2024-02-01 14:30
# Database Management System Prof. Supriya Ghatak 2024-02-01 13:30 2024-02-01 14:30
# Course Name: Database Management System
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 01-02-2024 13:30 - 01-02-2024 14:30
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
# 2024-02-01 14:45
# 2024-02-01 15:45
# Operations Management Prof. Vishal Ashok Wankhede 2024-02-01 14:45 2024-02-01 15:45
# Course Name: Operations Management
# Faculty Name: Prof. Vishal Ashok Wankhede
# Time Slot: 01-02-2024 14:45 - 01-02-2024 15:45
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
#
#
# 2024-02-02 09:00
# 2024-02-02 10:00
# Game Theory Prof. Amit Srivastava 2024-02-02 09:00 2024-02-02 10:00
# Course Name: Game Theory
# Faculty Name: Prof. Amit Srivastava
# Time Slot: 02-02-2024 09:00 - 02-02-2024 10:00
# Program Name: IPM_02_SECA
# Program: IPM
# Year: 02
# Section: SECA
#
#
#
#
# Sheet: IPM_02_SECB
#
# 2024-01-29 09:00
# 2024-01-29 10:00
# Operations Management Prof. Vishal Ashok Wankhede 2024-01-29 09:00 2024-01-29 10:00
# Course Name: Operations Management
# Faculty Name: Prof. Vishal Ashok Wankhede
# Time Slot: 29-01-2024 09:00 - 29-01-2024 10:00
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-01-29 11:30
# 2024-01-29 12:30
# Business Research Method Prof. Ramesh Roshan Das Guru 2024-01-29 11:30 2024-01-29 12:30
# Course Name: Business Research Method
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 29-01-2024 11:30 - 29-01-2024 12:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-01-29 13:30
# 2024-01-29 14:30
# Foreign Language II Prof. Durba Banerjee 2024-01-29 13:30 2024-01-29 14:30
# Course Name: Foreign Language II
# Faculty Name: Prof. Durba Banerjee
# Time Slot: 29-01-2024 13:30 - 29-01-2024 14:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-01-29 14:45
# 2024-01-29 15:45
# Advance Communication Skill Prof. Gargi Roy 2024-01-29 14:45 2024-01-29 15:45
# Course Name: Advance Communication Skill
# Faculty Name: Prof. Gargi Roy
# Time Slot: 29-01-2024 14:45 - 29-01-2024 15:45
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
#
#
# 2024-01-30 09:00
# 2024-01-30 10:00
# Creativity & Innovation Prof. Abhishek Yadav 2024-01-30 09:00 2024-01-30 10:00
# Course Name: Creativity & Innovation
# Faculty Name: Prof. Abhishek Yadav
# Time Slot: 30-01-2024 09:00 - 30-01-2024 10:00
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-01-30 10:15
# 2024-01-30 11:15
# Advance Communication Skill Prof. Gargi Roy 2024-01-30 10:15 2024-01-30 11:15
# Course Name: Advance Communication Skill
# Faculty Name: Prof. Gargi Roy
# Time Slot: 30-01-2024 10:15 - 30-01-2024 11:15
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-01-30 11:30
# 2024-01-30 12:30
# Database Management System Prof. Supriya Ghatak 2024-01-30 11:30 2024-01-30 12:30
# Course Name: Database Management System
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 30-01-2024 11:30 - 30-01-2024 12:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-01-30 13:30
# 2024-01-30 14:30
# Business Ethics & Values Prof. Johnson A Minz 2024-01-30 13:30 2024-01-30 14:30
# Course Name: Business Ethics & Values
# Faculty Name: Prof. Johnson A Minz
# Time Slot: 30-01-2024 13:30 - 30-01-2024 14:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
#
#
# 2024-01-31 13:30
# 2024-01-31 14:30
# Business Research Method Prof. Ramesh Roshan Das Guru 2024-01-31 13:30 2024-01-31 14:30
# Course Name: Business Research Method
# Faculty Name: Prof. Ramesh Roshan Das Guru
# Time Slot: 31-01-2024 13:30 - 31-01-2024 14:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
#
#
# 2024-02-01 11:30
# 2024-02-01 12:30
# Database Management System Prof. Supriya Ghatak 2024-02-01 11:30 2024-02-01 12:30
# Course Name: Database Management System
# Faculty Name: Prof. Supriya Ghatak
# Time Slot: 01-02-2024 11:30 - 01-02-2024 12:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-02-01 13:30
# 2024-02-01 14:30
# Operations Management Prof. Vishal Ashok Wankhede 2024-02-01 13:30 2024-02-01 14:30
# Course Name: Operations Management
# Faculty Name: Prof. Vishal Ashok Wankhede
# Time Slot: 01-02-2024 13:30 - 01-02-2024 14:30
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-02-01 14:45
# 2024-02-01 15:45
# Business Ethics & Values Prof. Johnson A Minz 2024-02-01 14:45 2024-02-01 15:45
# Course Name: Business Ethics & Values
# Faculty Name: Prof. Johnson A Minz
# Time Slot: 01-02-2024 14:45 - 01-02-2024 15:45
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
#
#
# 2024-02-02 09:00
# 2024-02-02 10:00
# Foreign Language II Prof. Durba Banerjee 2024-02-02 09:00 2024-02-02 10:00
# Course Name: Foreign Language II
# Faculty Name: Prof. Durba Banerjee
# Time Slot: 02-02-2024 09:00 - 02-02-2024 10:00
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
# 2024-02-02 10:15
# 2024-02-02 11:15
# Game Theory Prof. Amit Srivastava 2024-02-02 10:15 2024-02-02 11:15
# Course Name: Game Theory
# Faculty Name: Prof. Amit Srivastava
# Time Slot: 02-02-2024 10:15 - 02-02-2024 11:15
# Program Name: IPM_02_SECB
# Program: IPM
# Year: 02
# Section: SECB
#
#
#
#
# Sheet: IPM_03_SECA
#
# 2024-01-29 10:15
# 2024-01-29 11:15
# Consumer Behaviour Prof. SK Abu Khalek 2024-01-29 10:15 2024-01-29 11:15
# Course Name: Consumer Behaviour
# Faculty Name: Prof. SK Abu Khalek
# Time Slot: 29-01-2024 10:15 - 29-01-2024 11:15
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-29 11:30
# 2024-01-29 12:30
# Digital Frameworks Prof. Srividya Raghavan 2024-01-29 11:30 2024-01-29 12:30
# Course Name: Digital Frameworks
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 29-01-2024 11:30 - 29-01-2024 12:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-29 13:30
# 2024-01-29 14:30
# Intellectual Property Rights Prof. Soumya Prakash Patra 2024-01-29 13:30 2024-01-29 14:30
# Course Name: Intellectual Property Rights
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 29-01-2024 13:30 - 29-01-2024 14:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-29 14:45
# 2024-01-29 15:45
# Introduction to Taxation Prof. Bharti Singh 2024-01-29 14:45 2024-01-29 15:45
# Course Name: Introduction to Taxation
# Faculty Name: Prof. Bharti Singh
# Time Slot: 29-01-2024 14:45 - 29-01-2024 15:45
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
#
#
# 2024-01-30 09:00
# 2024-01-30 10:00
# Project Management Prof. Ajith Tom James 2024-01-30 09:00 2024-01-30 10:00
# Course Name: Project Management
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 30-01-2024 09:00 - 30-01-2024 10:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-30 10:15
# 2024-01-30 11:15
# International Trade & Finance Prof. Suresh KG 2024-01-30 10:15 2024-01-30 11:15
# Course Name: International Trade & Finance
# Faculty Name: Prof. Suresh KG
# Time Slot: 30-01-2024 10:15 - 30-01-2024 11:15
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-30 11:30
# 2024-01-30 12:30
# E-commerce & Applications Prof. Raghunathan Krishnakumar 2024-01-30 11:30 2024-01-30 12:30
# Course Name: E-commerce & Applications
# Faculty Name: Prof. Raghunathan Krishnakumar
# Time Slot: 30-01-2024 11:30 - 30-01-2024 12:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-30 13:30
# 2024-01-30 14:30
# Media & Society Prof. Sanjay Kaushal 2024-01-30 13:30 2024-01-30 14:30
# Course Name: Media & Society
# Faculty Name: Prof. Sanjay Kaushal
# Time Slot: 30-01-2024 13:30 - 30-01-2024 14:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-30 14:45
# 2024-01-30 15:45
# Industrial Economics Prof. Muhammed Ashiq V 2024-01-30 14:45 2024-01-30 15:45
# Course Name: Industrial Economics
# Faculty Name: Prof. Muhammed Ashiq V
# Time Slot: 30-01-2024 14:45 - 30-01-2024 15:45
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-30 16:00
# 2024-01-30 17:00
# Economic Growth & Development Prof. Thasni T 2024-01-30 16:00 2024-01-30 17:00
# Course Name: Economic Growth & Development
# Faculty Name: Prof. Thasni T
# Time Slot: 30-01-2024 16:00 - 30-01-2024 17:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-30 17:15
# 2024-01-30 18:15
# Supply Chain & Logistics Prof. Shashank Kumar 2024-01-30 17:15 2024-01-30 18:15
# Course Name: Supply Chain & Logistics
# Faculty Name: Prof. Shashank Kumar
# Time Slot: 30-01-2024 17:15 - 30-01-2024 18:15
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
#
#
# 2024-01-31 09:00
# 2024-01-31 10:00
# Introduction to Taxation Prof. Bharti Singh 2024-01-31 09:00 2024-01-31 10:00
# Course Name: Introduction to Taxation
# Faculty Name: Prof. Bharti Singh
# Time Slot: 31-01-2024 09:00 - 31-01-2024 10:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-31 10:15
# 2024-01-31 11:15
# Digital Frameworks Prof. Srividya Raghavan 2024-01-31 10:15 2024-01-31 11:15
# Course Name: Digital Frameworks
# Faculty Name: Prof. Srividya Raghavan
# Time Slot: 31-01-2024 10:15 - 31-01-2024 11:15
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-31 11:30
# 2024-01-31 12:30
# Intellectual Property Rights Prof. Soumya Prakash Patra 2024-01-31 11:30 2024-01-31 12:30
# Course Name: Intellectual Property Rights
# Faculty Name: Prof. Soumya Prakash Patra
# Time Slot: 31-01-2024 11:30 - 31-01-2024 12:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-31 14:45
# 2024-01-31 15:45
# New Venture Planning & Entrepreneurship Dev. Prof. Atma Prakash Ojha 2024-01-31 14:45 2024-01-31 15:45
# Course Name: New Venture Planning & Entrepreneurship Dev.
# Faculty Name: Prof. Atma Prakash Ojha
# Time Slot: 31-01-2024 14:45 - 31-01-2024 15:45
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-01-31 16:00
# 2024-01-31 17:00
# Management Insights from Bhagwat Geeta Prof. Vittal Rangan 2024-01-31 16:00 2024-01-31 17:00
# Course Name: Management Insights from Bhagwat Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 31-01-2024 16:00 - 31-01-2024 17:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
#
#
# 2024-02-01 09:00
# 2024-02-01 10:00
# Project Management Prof. Ajith Tom James 2024-02-01 09:00 2024-02-01 10:00
# Course Name: Project Management
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 01-02-2024 09:00 - 01-02-2024 10:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-01 11:30
# 2024-02-01 12:30
# E-commerce & Applications Prof. Raghunathan Krishnakumar 2024-02-01 11:30 2024-02-01 12:30
# Course Name: E-commerce & Applications
# Faculty Name: Prof. Raghunathan Krishnakumar
# Time Slot: 01-02-2024 11:30 - 01-02-2024 12:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-01 13:30
# 2024-02-01 14:30
# Media & Society Prof. Sanjay Kaushal 2024-02-01 13:30 2024-02-01 14:30
# Course Name: Media & Society
# Faculty Name: Prof. Sanjay Kaushal
# Time Slot: 01-02-2024 13:30 - 01-02-2024 14:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-01 14:45
# 2024-02-01 15:45
# Project Management Prof. Ajith Tom James 2024-02-01 14:45 2024-02-01 15:45
# Course Name: Project Management
# Faculty Name: Prof. Ajith Tom James
# Time Slot: 01-02-2024 14:45 - 01-02-2024 15:45
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-01 16:00
# 2024-02-01 17:00
# Economic Growth & Development Prof. Thasni T 2024-02-01 16:00 2024-02-01 17:00
# Course Name: Economic Growth & Development
# Faculty Name: Prof. Thasni T
# Time Slot: 01-02-2024 16:00 - 01-02-2024 17:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-01 17:15
# 2024-02-01 18:15
# Supply Chain & Logistics Prof. Shashank Kumar 2024-02-01 17:15 2024-02-01 18:15
# Course Name: Supply Chain & Logistics
# Faculty Name: Prof. Shashank Kumar
# Time Slot: 01-02-2024 17:15 - 01-02-2024 18:15
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
#
#
# 2024-02-02 10:15
# 2024-02-02 11:15
# Consumer Behaviour Prof. SK Abu Khalek 2024-02-02 10:15 2024-02-02 11:15
# Course Name: Consumer Behaviour
# Faculty Name: Prof. SK Abu Khalek
# Time Slot: 02-02-2024 10:15 - 02-02-2024 11:15
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-02 11:30
# 2024-02-02 12:30
# Consumer Behaviour Prof. SK Abu Khalek 2024-02-02 11:30 2024-02-02 12:30
# Course Name: Consumer Behaviour
# Faculty Name: Prof. SK Abu Khalek
# Time Slot: 02-02-2024 11:30 - 02-02-2024 12:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-02 13:30
# 2024-02-02 14:30
# International Trade & Finance Prof. Suresh KG 2024-02-02 13:30 2024-02-02 14:30
# Course Name: International Trade & Finance
# Faculty Name: Prof. Suresh KG
# Time Slot: 02-02-2024 13:30 - 02-02-2024 14:30
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-02 14:45
# 2024-02-02 15:45
# Industrial Economics Prof. Muhammed Ashiq V 2024-02-02 14:45 2024-02-02 15:45
# Course Name: Industrial Economics
# Faculty Name: Prof. Muhammed Ashiq V
# Time Slot: 02-02-2024 14:45 - 02-02-2024 15:45
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
# 2024-02-02 16:00
# 2024-02-02 17:00
# Management Insights from Bhagwat Geeta Prof. Vittal Rangan 2024-02-02 16:00 2024-02-02 17:00
# Course Name: Management Insights from Bhagwat Geeta
# Faculty Name: Prof. Vittal Rangan
# Time Slot: 02-02-2024 16:00 - 02-02-2024 17:00
# Program Name: IPM_03_SECA
# Program: IPM
# Year: 03
# Section: SECA
#
#
#
#
# Sheet: IPM_03_SECB
